# %%
import pandas as pd
val1 = [[80,69,83,98],[71,90,69,66], [74,72,72,95]]
val2 =[[68,70,84,70], [65,91,90,66], [78,94,96,64]]
val3 = [[79,99,95,90], [99,76,81,97], [95,80,62,84]]
idx1 = ["송중기", "박보검", "김나연"]
idx2 = ["권보아", "김범수", "박효신"]
idx3 = ["김유정", "홍은희", "이세영"]
col1 = ["국어", "수학", "영어", "과학"]
col2 = ["국어", "수학", "영어", "사회"]
df1 = pd.DataFrame(val1, index=idx1, columns=col1)
df2 = pd.DataFrame(val2, index=idx2, columns=col1)
df3 = pd.DataFrame([[65,82], [85,60], [75,78]], index=idx1, columns=["사회", "일어"])
df4 = df2.reindex(columns=["영어", "과학", "수학", "국어"])
df5 = pd.DataFrame(val3, index=idx3, columns=col2)

# %%
df1
# Out:
#      국어  수학  영어  과학
# 송중기  80  69  83  98
# 박보검  71  90  69  66
# 김나연  74  72  72  95

# %%
#pd.concat([df1,...,dfn], join=방식, axis=축)

# %%
pd.concat([df1,df2])
# Out:
#      국어  수학  영어  과학
# 송중기  80  69  83  98
# 박보검  71  90  69  66
# 김나연  74  72  72  95
# 권보아  68  70  84  70
# 김범수  65  91  90  66
# 박효신  78  94  96  64

# %%
pd.concat([df1,df3], axis=1)
# Out:
#      국어  수학  영어  과학  사회  일어
# 송중기  80  69  83  98  65  82
# 박보검  71  90  69  66  85  60
# 김나연  74  72  72  95  75  78

# %%
df1
# Out:
#      국어  수학  영어  과학
# 송중기  80  69  83  98
# 박보검  71  90  69  66
# 김나연  74  72  72  95

# %%
df4
# Out:
#      영어  과학  수학  국어
# 권보아  84  70  70  68
# 김범수  90  66  91  65
# 박효신  96  64  94  78

# %%
pd.concat([df1,df4])
# Out:
#      국어  수학  영어  과학
# 송중기  80  69  83  98
# 박보검  71  90  69  66
# 김나연  74  72  72  95
# 권보아  68  70  84  70
# 김범수  65  91  90  66
# 박효신  78  94  96  64

# %%
df1
# Out:
#      국어  수학  영어  과학
# 송중기  80  69  83  98
# 박보검  71  90  69  66
# 김나연  74  72  72  95

# %%
df5
# Out:
#      국어  수학  영어  사회
# 김유정  79  99  95  90
# 홍은희  99  76  81  97
# 이세영  95  80  62  84

# %%
pd.concat([df1,df5], join="inner")
# Out:
#      국어  수학  영어
# 송중기  80  69  83
# 박보검  71  90  69
# 김나연  74  72  72
# 김유정  79  99  95
# 홍은희  99  76  81
# 이세영  95  80  62

# %%
pd.concat([df1,df5],join="outer")
# Out:
#      국어  수학  영어    과학    사회
# 송중기  80  69  83  98.0   NaN
# 박보검  71  90  69  66.0   NaN
# 김나연  74  72  72  95.0   NaN
# 김유정  79  99  95   NaN  90.0
# 홍은희  99  76  81   NaN  97.0
# 이세영  95  80  62   NaN  84.0

# %%
pd.concat([df1,df5.reindex(columns=df1.columns,fill_value="불참")])
# Out:
#      국어  수학  영어  과학
# 송중기  80  69  83  98
# 박보검  71  90  69  66
# 김나연  74  72  72  95
# 김유정  79  99  95  불참
# 홍은희  99  76  81  불참
# 이세영  95  80  62  불참

# %%
import pandas as pd
a1 = ["송중기", "김나연", "박보검", "권보아", "이효리", "김범수"]
b1 = ["별다방", "콩다방", "별다방", "별다방", "별다방", "콩다방"]
c1 = ["카페라떼", "아이스티", "카페라떼", "카페라떼", "아이스티", "카페라떼"]
df1 = pd.DataFrame([a1, b1,c1], index=["이름", "업체", "제품"]).T
df2 = pd.read_csv("https://raw.githubusercontent.com/"
                  "panda-kim/pandas/main/value_counts_01.csv")

# %%
#df.value_counts([열1,열2,..,열n], ascending=bool, normalize=bool)

# %%
df1
# Out:
#     이름   업체    제품
# 0  송중기  별다방  카페라떼
# 1  김나연  콩다방  아이스티
# 2  박보검  별다방  카페라떼
# 3  권보아  별다방  카페라떼
# 4  이효리  별다방  아이스티
# 5  김범수  콩다방  카페라떼

# %%
df1.value_counts("제품")
# Out:
# 제품
# 카페라떼    4
# 아이스티    2
# dtype: int64

# %%
df1.value_counts(["업체","제품"], ascending=True)
# Out:
# 업체   제품
# 별다방  아이스티    1
# 콩다방  아이스티    1
#      카페라떼    1
# 별다방  카페라떼    3
# dtype: int64

# %%
df1.value_counts(['업체','제품'], normalize=True) #normalize 비율로 나타내준다
# Out:
# 업체   제품
# 별다방  카페라떼    0.500000
#      아이스티    0.166667
# 콩다방  아이스티    0.166667
#      카페라떼    0.166667
# dtype: float64

# %%
df2
# Out:
#       이름  반  선택  점수
# 0    강지환  1  지학  99
# 1    고동현  9  지학  99
# 2    김도윤  4  화학  99
# 3    김사권  8  지학  99
# 4    김서원  2  지학  99
# ..   ... ..  ..  ..
# 369  박성웅  4  지학  60
# 370  박원호  7  물리  60
# 371  박재광  9  지학  60
# 372  박철현  2  지학  60
# 373  변요한  7  화학  60
#
# [374 rows x 4 columns]

# %%
df2.value_counts("선택")
# Out:
# 선택
# 생물    105
# 화학     97
# 지학     89
# 물리     83
# dtype: int64

# %%
#탑3만 남기고싶을때 불리언인덱싱 하면된다
#내림차순이니 top을 구할땐 슬라이싱만 하면된다.
#슬라이싱은loc와 iloc로가능한데 iloc가 편리

# %%
df2.value_counts("선택").iloc[:3] #상위3개과목
# Out:
# 선택
# 생물    105
# 화학     97
# 지학     89
# dtype: int64

# %%
df2.loc[df2["선택"].isin(df2.value_counts("선택").iloc[:3].index)]
# Out:
#       이름  반  선택  점수
# 0    강지환  1  지학  99
# 1    고동현  9  지학  99
# 2    김도윤  4  화학  99
# 3    김사권  8  지학  99
# 4    김서원  2  지학  99
# ..   ... ..  ..  ..
# 368  박상욱  4  화학  60
# 369  박성웅  4  지학  60
# 371  박재광  9  지학  60
# 372  박철현  2  지학  60
# 373  변요한  7  화학  60
#
# [291 rows x 4 columns]
